# %%
#data frame functions

# %%
import pandas as pd
df=pd.read_csv(r'/content/workout(Sheet1).csv')
df
# Out:
#    flower  pen
# 0       1   11
# 1       2   12
# 2       3   13
# 3       4   14
# 4       5   15
# 5       6   16
# 6       7   17
# 7       8   18
# 8       9   19
# 9      10   20

# %%
df.columns
# this will provide the no of columns,columns present in that dataframe
# Out:
# Index(['flower', 'pen'], dtype='object')

# %%
df.shape # it will provide tuple of values as no of rows and columns
# Out:
# (10, 2)

# %%
df.size
# Out:
# 20

# %%
df.head() #it will give every row
# Out:
#    flower  pen
# 0       1   11
# 1       2   12
# 2       3   13
# 3       4   14
# 4       5   15

# %%
df.head(2) # it will give first 2 rows from top
# Out:
#    flower  pen
# 0       1   11
# 1       2   12

# %%
df.tail(2) #it will show last 2 rows from tail(end)
# Out:
#    flower  pen
# 8       9   19
# 9      10   20

# %%
df.tail()
# Out:
#    flower  pen
# 5       6   16
# 6       7   17
# 7       8   18
# 8       9   19
# 9      10   20

# %%
df.describe() # it will show the description of numerical data
# Out:
#          flower       pen
# count  10.00000  10.00000
# mean    5.50000  15.50000
# std     3.02765   3.02765
# min     1.00000  11.00000
# 25%     3.25000  13.25000
# 50%     5.50000  15.50000
# 75%     7.75000  17.75000
# max    10.00000  20.00000

# %%
df.info() # it is giving basic description about the dataset
# same like describe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   flower  10 non-null     int64
#  1   pen     10 non-null     int64
# dtypes: int64(2)
# memory usage: 288.0 bytes

# %%
df2=pd.read_csv(r'/content/testingdata(Sheet1) (1).csv')
df2 #reading the csv
# Out:
#    flower  pen    no  values  tags
# 0       1   11   3.0     NaN   NaN
# 1       2   12   4.0    56.0   0.0
# 2       3   13   NaN     NaN   1.0
# 3       4   14   8.0    32.0   NaN
# 4       5   15  34.0    44.0   1.0
# 5       6   16  67.0     NaN   0.0
# 6       7   17  45.0    32.0   NaN
# 7       8   18  32.0     NaN   NaN
# 8       9   19   2.0    12.0   1.0
# 9      10   20   1.0     NaN   0.0

# %%
df2.head()
# Out:
#    flower  pen    no  values  tags
# 0       1   11   3.0     NaN   NaN
# 1       2   12   4.0    56.0   0.0
# 2       3   13   NaN     NaN   1.0
# 3       4   14   8.0    32.0   NaN
# 4       5   15  34.0    44.0   1.0

# %%
df2.shape
# Out:
# (10, 5)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   flower  10 non-null     int64
#  1   pen     10 non-null     int64
#  2   no      9 non-null      float64
#  3   values  5 non-null      float64
#  4   tags    6 non-null      float64
# dtypes: float64(3), int64(2)
# memory usage: 528.0 bytes

# %%
df2.describe()
# Out:
#          flower       pen         no     values      tags
# count  10.00000  10.00000   9.000000   5.000000  6.000000
# mean    5.50000  15.50000  21.777778  35.200000  0.500000
# std     3.02765   3.02765  23.768560  16.346253  0.547723
# min     1.00000  11.00000   1.000000  12.000000  0.000000
# 25%     3.25000  13.25000   3.000000  32.000000  0.000000
# 50%     5.50000  15.50000   8.000000  32.000000  0.500000
# 75%     7.75000  17.75000  34.000000  44.000000  1.000000
# max    10.00000  20.00000  67.000000  56.000000  1.000000
